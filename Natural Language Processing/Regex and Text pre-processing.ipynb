# %% [markdown]
# **<font size="5">1. Create a data source:<br>**
# <font size="3">a) Read the content of the book &#39;Indian Fairy Tales&#39; from the gutenberg_book.txt file.

# %%
with open("gutenberg_book.txt",'r') as file:
  text = file.read()
  print(text)
# Out:
# ﻿The Project Gutenberg eBook, Indian Fairy Tales, Edited by Joseph Jacobs,
# Illustrated by John D. Batten and Gloria Cardew
#
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# For more details please mail us at: queries@gutenberg.com, support@gutenberg-books.com
#
#
# Title: Indian Fairy Tales
#
#
# Editor: Joseph Jacobs
#
# Release Date: March 13, 2003  [eBook #7128]
# Most recently updated: May 1, 2012
#
# Language: English
#
# Character set encoding: UTF-8
#
#
# ***START OF THE PROJECT GUTENBERG EBOOK INDIAN FAIRY TALES***
#
#
# E-text prepared by Delphine Lettau, Charles Franks, and the Online
# Distributed Proofreading Team and revised by Sankar Viswanathan, Fritz
# Ohrenschall, Sania Ali Mirza, and the Online Distributed Proofreading Team
# ...

# %% [markdown]
# <font size="5"><b>2. Regular expressions:</b>

# %% [markdown]
# <font size="3">a) Extract the Title, Editor, Release Date, Most recently update, Language and Character set
# encoding from the book.

# %%
import re

title_pattern = r"Title: (.+)"
editor_pattern = r"Editor: (.+)"
release_date_pattern = r"Release Date: (.+)"
recent_update_pattern = r"Most recently updated: (.+)"
language_pattern = r"Language: (.+)"
charset_pattern = r"Character set encoding: (.+)"

title = re.search(title_pattern, text).group(1)
editor = re.search(editor_pattern, text).group(1)
release_date = re.search(release_date_pattern, text).group(1)
recent_update = re.search(recent_update_pattern, text).group(1)
language = re.search(language_pattern, text).group(1)
charset_encoding = re.search(charset_pattern, text).group(1)

# Print the extracted information
print("Title:", title)
print("Editor:", editor)
print("Release Date:", release_date)
print("Most Recently Update:", recent_update)
print("Language:", language)
print("Character Set Encoding:", charset_encoding)
# Out:
# Title: Indian Fairy Tales
# Editor: Joseph Jacobs
# Release Date: March 13, 2003  [eBook #7128]
# Most Recently Update: May 1, 2012
# Language: English
# Character Set Encoding: UTF-8

# %% [markdown]
# b) Extract all email ids.

# %%
email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
email_ids = re.findall(email_pattern, text)
email_ids
# Out:
# ['queries@gutenberg.com', 'support@gutenberg-books.com']

# %% [markdown]
# c) Extract usernames from email ids.

# %%
usernames = [re.search(r"([A-Za-z0-9._%+-]+)@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}", email).group(1) for email in email_ids]
usernames
# Out:
# ['queries', 'support']

# %% [markdown]
# d) Replace email ids with the email id &#39;support@christuniversity.in&#39;.

# %%
replaced_text = re.sub(email_pattern, 'support@christuniversity.in', text)
replaced_text
# Out:
# '\ufeffThe Project Gutenberg eBook, Indian Fairy Tales, Edited by Joseph Jacobs,\nIllustrated by John D. Batten and Gloria Cardew\n\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nFor more details please mail us at: support@christuniversity.in, support@christuniversity.in\n\n\nTitle: Indian Fairy Tales\n\n\nEditor: Joseph Jacobs\n\nRelease Date: March 13, 2003  [eBook #7128]\nMost recently updated: May 1, 2012\n\nLanguage: English\n\nCharacter set encoding: UTF-8\n\n\n***START OF THE PROJECT GUTENBERG EBOOK INDIAN FAIRY TALES***\n\n\nE-text prepared by Delphine Lettau, Charles Franks, and the Online\nDistributed Proofreading Team and revised by Sankar Viswanathan, Fritz\nOhrenschall, Sania Ali Mirza, and the Online Distributed Proofreading Team\n(http://www.pgdp.net) using pa
# ...

# %% [markdown]
# e) Extract all website URLs.

# %%
url_pattern = r'\bhttps?://[^\s<>"]+|www\.[^\s<>"]+\b'
urls = re.findall(url_pattern, text)
urls
# Out:
# ['www.gutenberg.org',
#  'http://www.pgdp.net)',
#  'http://archive.org)',
#  'http://www.gutenberg.org/files/7128/7128-h/7128-h.htm)',
#  'http://www.gutenberg.org/files/7128/7128-h.zip)',
#  'http://archive.org/details/indiantales00jacorich',
#  'http://www.gutenberg.org']

# %% [markdown]
# f) Extract all 9-lettered words in the text and print the list of those words.

# %%
nine= re.findall(r'\b\w{9}\b', text)
nine
# Out:
# ['Gutenberg',
#  'Gutenberg',
#  'gutenberg',
#  'gutenberg',
#  'gutenberg',
#  'Character',
#  'GUTENBERG',
#  'available',
#  'Gutenberg',
#  'gutenberg',
#  'gutenberg',
#  'available',
#  'Outwitted',
#  'emergency',
#  'exclaimed',
#  'stupidity',
#  'trickling',
#  'trembling',
#  'beseeched',
#  'exceeding',
#  'consented',
#  'gratitude',
#  'everybody',
#  'miserable',
#  'confusing',
#  'consented',
#  'stupidity',
#  'beginning',
#  'Perfectly',
#  'Talkative',
#  'spiritual',
#  'talkative',
#  'mountains',
#  'Beautiful',
#  'villagers',
#  'Whereupon',
#  'courtyard',
#  'universal',
#  'courtyard',
#  'courtiers',
#  'expecting',
#  'something',
#  'excellent',
#  'refrained',
#  'Gutenberg',
#  'Professor',
#  'Gutenberg',
#  'Gutenberg',
#  'volunteer',
#  'Gutenberg',
#  'confirmed',
#  'copyright',
#  'gutenberg',
#  'Gutenberg',
#  'including',
#  'donations',
#  'Gutenberg',
#  'subscribe']

# %% [markdown]
# <font size="5"><b>3. Text Processing:</b>

# %% [markdown]
# <font size="3">a) Lowercase the book content and write it into a file.

# %%
import nltk

# %%
normalised_text = text.lower()

output_file_path = "lower_CAC.txt"

with open("lower_CAC.txt",'w') as file:
  for sentence in normalised_text:
    file.write(sentence)

print("Results written to", output_file_path)
# Out:
# Results written to lower_CAC.txt

# %% [markdown]
# b) Remove all punctuation from the book. Print the list of punctuation that were removed.

# %%
with open("lower_CAC.txt",'r') as file:
  text_1 = file.read()

from nltk.tokenize import word_tokenize
import string
import re
nltk.download('punkt')

tokens = word_tokenize(text_1)
pattern = r'[^\w\s]'
new_text1 = re.sub(pattern, '', text_1)

punc_removed = re.findall(pattern, text_1)

output_file_path = "punc.txt"

with open('punc.txt', 'w') as file:
    file.write(new_text1+'\n\n')
    file.write(str(punc_removed))

print("Results written to", output_file_path)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Results written to punc.txt

# %% [markdown]
# c) Remove stopwords using Stopwords English corpus and print list of words after removing
# stopwords.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
sw = stopwords.words("english")

# %%
no_stopwords = [word for word in tokens if word.lower() not in sw]

stopwords_list = list(sw)

print(stopwords_list)
print(no_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [markdown]
# d) Perform lemmatization on the words using Wordnet Lemmatizer and print the list of all
# word-lemma pair. For example: studies-study

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words = word_tokenize(new_text1)

lemmatizer = WordNetLemmatizer()

word_lemma_pairs = []

for word in words:
    lemma = lemmatizer.lemmatize(word)
    word_lemma_pairs.append((word, lemma))

print(word_lemma_pairs)
# Out:
# [('the', 'the'), ('project', 'project'), ('gutenberg', 'gutenberg'), ('ebook', 'ebook'), ('indian', 'indian'), ('fairy', 'fairy'), ('tales', 'tale'), ('edited', 'edited'), ('by', 'by'), ('joseph', 'joseph'), ('jacobs', 'jacob'), ('illustrated', 'illustrated'), ('by', 'by'), ('john', 'john'), ('d', 'd'), ('batten', 'batten'), ('and', 'and'), ('gloria', 'gloria'), ('cardew', 'cardew'), ('this', 'this'), ('ebook', 'ebook'), ('is', 'is'), ('for', 'for'), ('the', 'the'), ('use', 'use'), ('of', 'of'), ('anyone', 'anyone'), ('anywhere', 'anywhere'), ('at', 'at'), ('no', 'no'), ('cost', 'cost'), ('and', 'and'), ('with', 'with'), ('almost', 'almost'), ('no', 'no'), ('restrictions', 'restriction'), ('whatsoever', 'whatsoever'), ('you', 'you'), ('may', 'may'), ('copy', 'copy'), ('it', 'it'), ('give', 'give'), ('it', 'it'), ('away', 'away'), ('or', 'or'), ('reuse', 'reuse'), ('it', 'it'), ('under', 'under'), ('the', 'the'), ('terms', 'term'), ('of', 'of'), ('the', 'the'), ('project', 'project'),
# ...

# %% [markdown]
# e) Perform parts-of-speech tagging and print the list of word-POS pair. Display named entities
# using ne_chunk.

# %%
import nltk
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_tags = pos_tag(words)

# Print the list of word-POS pairs
for word, pos in pos_tags:
    print(f"{word}-{pos}")
# Out:
# the-DT
# project-NN
# gutenberg-NN
# ebook-NN
# indian-JJ
# fairy-NN
# tales-NNS
# edited-VBN
# by-IN
# joseph-NN
# jacobs-NN
# illustrated-VBN
# by-IN
# john-NN
# d-NN
# batten-NN
# and-CC
# gloria-NN
# cardew-NN
# this-DT
# ebook-NN
# is-VBZ
# for-IN
# the-DT
# use-NN
# of-IN
# anyone-NN
# anywhere-RB
# at-IN
# no-DT
# cost-NN
# and-CC
# with-IN
# almost-RB
# no-DT
# restrictions-NNS
# whatsoever-IN
# you-PRP
# may-MD
# copy-VB
# it-PRP
# give-VB
# it-PRP
# away-RB
# or-CC
# reuse-VB
# it-PRP
# under-IN
# the-DT
# terms-NNS
# of-IN
# the-DT
# project-NN
# gutenberg-NN
# license-NN
# included-VBD
# with-IN
# this-DT
# ebook-NN
# or-CC
# online-NN
# at-IN
# wwwgutenbergorg-NN
# for-IN
# more-JJR
# details-NNS
# please-VB
# mail-VB
# us-PRP
# at-IN
# queriesgutenbergcom-NN
# supportgutenbergbookscom-NN
# title-NN
# indian-JJ
# fairy-NN
# tales-NNS
# editor-NN
# joseph-NN
# jacobs-NN
# release-NN
# date-NN
# march-NN
# 13-CD
# 2003-CD
# ebook-NN
# 7128-CD
# most-RBS
# recently-RB
# ...

# %%
from nltk import ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')
# !pip install svgling
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.3 MB/s eta 0:00:00
# ...

# %%
ne_tree = ne_chunk(nltk.pos_tag(words))
ne_tree
# Out:
# Tree('S', [('the', 'DT'), ('project', 'NN'), ('gutenberg', 'NN'), ('ebook', 'NN'), ('indian', 'JJ'), ('fairy', 'NN'), ('tales', 'NNS'), ('edited', 'VBN'), ('by', 'IN'), ('joseph', 'NN'), ('jacobs', 'NN'), ('illustrated', 'VBN'), ('by', 'IN'), ('john', 'NN'), ('d', 'NN'), ('batten', 'NN'), ('and', 'CC'), ('gloria', 'NN'), ('cardew', 'NN'), ('this', 'DT'), ('ebook', 'NN'), ('is', 'VBZ'), ('for', 'IN'), ('the', 'DT'), ('use', 'NN'), ('of', 'IN'), ('anyone', 'NN'), ('anywhere', 'RB'), ('at', 'IN'), ('no', 'DT'), ('cost', 'NN'), ('and', 'CC'), ('with', 'IN'), ('almost', 'RB'), ('no', 'DT'), ('restrictions', 'NNS'), ('whatsoever', 'IN'), ('you', 'PRP'), ('may', 'MD'), ('copy', 'VB'), ('it', 'PRP'), ('give', 'VB'), ('it', 'PRP'), ('away', 'RB'), ('or', 'CC'), ('reuse', 'VB'), ('it', 'PRP'), ('under', 'IN'), ('the', 'DT'), ('terms', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('project', 'NN'), ('gutenberg', 'NN'), ('license', 'NN'), ('included', 'VBD'), ('with', 'IN'), ('this', 'DT'), ('ebook', 'N
# ...

# %% [markdown]
# f) Extract and print all the nouns and pronouns in the text. NOTE: use
# nltk.help.upenn_tagset() to get the tag meanings.

# %% [markdown]
# g) Using spacy display the book content with named entities highlighted.

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Project Gutenberg eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fairy Tales
# ...

# %% [markdown]
# h) Extract the names of person, location, geo-political entities, cardinal numbers, language
# and date from the book using spacy.

# %% [markdown]
# i) Using wordnet extract words from the book which are fall under the category of: water lily,
# canaine, bird, plant, lake, turtle

# %% [markdown]
# j) Find 20 most common words and plot the graph.

# %%
from nltk.corpus import brown
nltk.download('brown')
words = brown.words()
words
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
from nltk import FreqDist
f = FreqDist(words)

# %%
f.plot(20)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# k) Find the term-frequency of &quot;Gutenberg&quot; in the book.

# %%
FreqDist("Gutenberg")
# Out:
# FreqDist({'e': 2, 'G': 1, 'u': 1, 't': 1, 'n': 1, 'b': 1, 'r': 1, 'g': 1})

# %% [markdown]
# l) Find the word that appeared maximum number of times in the book (excluding stopwords).
