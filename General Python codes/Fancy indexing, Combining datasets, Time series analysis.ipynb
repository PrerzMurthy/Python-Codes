# %% [markdown]
# ## Importing libraries and dataset

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:\\Users\\Prerana Murthy\\Documents\\Christ\\MSc\\Python\\data1.csv")
df1
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#        Unnamed: 4
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
df2 = pd.read_csv("C:\\Users\\Prerana Murthy\\Documents\\Christ\\MSc\\Python\\data2.csv")
df2
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ## Fancy indexing in numpy

# %%
array1 = df1["Price Each"].to_numpy()
array1
# Out:
# array(['11.95', nan, '99.99', ..., '2.99', '3.84', '14.95'], dtype=object)

# %%
#demonstrating fancy indexing - we can pass a single list or array of indices to obtain t
indices = [0,2,12]
array1[indices]
# Out:
# array(['11.95', '99.99', '14.95'], dtype=object)

# %%
# fancy indexing works in multiple dimensions
indices1 = np.array([[0,2],[6,12]])
array1[indices1]
# Out:
# array([['11.95', '99.99'],
#        ['11.95', '14.95']], dtype=object)

# %% [markdown]
# ## Numpy structured arrays

# %%
new_data= [('Name', (np.str_, 32)), ('reg_no', np.int32), ('school_name', (np.str_,32))]
new_data
# Out:
# [('Name', (numpy.str_, 32)),
#  ('reg_no', numpy.int32),
#  ('school_name', (numpy.str_, 32))]

# %%
new_array = np.array([('Priya',101 , 'Presidency'), ('Ram', 102, 'Christ'), ('Raja', 103, 'Christ'), ('Ria', 104, 'Presidency'),('Abhi',105,'Kumarans')], dtype = new_data)
new_array
# Out:
# array([('Priya', 101, 'Presidency'), ('Ram', 102, 'Christ'),
#        ('Raja', 103, 'Christ'), ('Ria', 104, 'Presidency'),
#        ('Abhi', 105, 'Kumarans')],
#       dtype=[('Name', '<U32'), ('reg_no', '<i4'), ('school_name', '<U32')])

# %%
sort = np.sort(new_array, order = 'Name')
sort
# Out:
# array([('Abhi', 105, 'Kumarans'), ('Priya', 101, 'Presidency'),
#        ('Raja', 103, 'Christ'), ('Ram', 102, 'Christ'),
#        ('Ria', 104, 'Presidency')],
#       dtype=[('Name', '<U32'), ('reg_no', '<i4'), ('school_name', '<U32')])

# %%
new_array[4]
# Out:
# ('Abhi', 105, 'Kumarans')

# %% [markdown]
# ## Combining datasets in pandas

# %%
data1 = df1.head(10)
data1
# Out:
#   Order ID                     Product Quantity Ordered Price Each  Unnamed: 4
# 0   176558        USB-C Charging Cable                2      11.95         NaN
# 1      NaN                         NaN              NaN        NaN         NaN
# 2   176559  Bose SoundSport Headphones                1      99.99         NaN
# 3   176560                Google Phone                1        600         NaN
# 4   176560            Wired Headphones                1      11.99         NaN
# 5   176561            Wired Headphones                1      11.99         NaN
# 6   176562        USB-C Charging Cable                1      11.95         NaN
# 7   176563  Bose SoundSport Headphones                1      99.99         NaN
# 8   176564        USB-C Charging Cable                1      11.95         NaN
# 9   176565          Macbook Pro Laptop                1       1700         NaN

# %%
data2 = df2.head(10)
data2
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9 non-null      object
#  1   Product           9 non-null      object
#  2   Quantity Ordered  9 non-null      object
#  3   Price Each        9 non-null      object
#  4   Unnamed: 4        0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 528.0+ bytes

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         10 non-null     object
#  1   Model                10 non-null     object
#  2   Sales_in_thousands   10 non-null     float64
#  3   __year_resale_value  9 non-null      float64
#  4   Vehicle_type         10 non-null     object
#  5   Price_in_thousands   9 non-null      float64
#  6   Engine_size          10 non-null     float64
#  7   Horsepower           10 non-null     float64
#  8   Wheelbase            10 non-null     float64
#  9   Width                10 non-null     float64
#  10  Length               10 non-null     float64
#  11  Curb_weight          10 non-null     float64
#  12  Fuel_capacity        10 non-null     float64
#  13  Fuel_efficiency      10 non-null     float64
#  14  Latest_Launch        10 non-null     object
# ...

# %%
data_comb = pd.concat([df1,df2], axis=1, join='inner')
data_comb
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     176558        USB-C Charging Cable                2      11.95
# 1        NaN                         NaN              NaN        NaN
# 2     176559  Bose SoundSport Headphones                1      99.99
# 3     176560                Google Phone                1        600
# 4     176560            Wired Headphones                1      11.99
# ..       ...                         ...              ...        ...
# 152   176702       AA Batteries (4-pack)                1       3.84
# 153   176703                20in Monitor                1     109.99
# 154   176704       AA Batteries (4-pack)                2       3.84
# 155   176705    Lightning Charging Cable                2      14.95
# 156   176706    Lightning Charging Cable                1      14.95
#
#      Unnamed: 4 Manufacturer    Model  Sales_in_thousands  \
# 0           NaN        Acura  Integra              16.919
# ...

# %% [markdown]
# ## Time series analysis using pandas

# %%
df2["Latest_Launch"].min(),df2["Latest_Launch"].max()
# Out:
# ('1/14/2012', '9/3/2011')

# %%
df2["Latest_launch"] = pd.to_datetime(df2["Latest_Launch"])
df2["Latest_Launch"]
# Out:
# 0        2/2/2012
# 1        6/3/2011
# 2        1/4/2012
# 3       3/10/2011
# 4       10/8/2011
#           ...
# 152     9/21/2011
# 153    11/24/2012
# 154     6/25/2011
# 155     4/26/2011
# 156    11/14/2011
# Name: Latest_Launch, Length: 157, dtype: object

# %%
df2["Latest_Launch"].min(), df2["Latest_Launch"].max()
# Out:
# ('1/14/2012', '9/3/2011')
