# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\Prerana Murthy\\Documents\\Christ\\MSc\\Python\\Student Performance new.csv")
data
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0             0        group B           bachelor's degree      standard
# 1             1        group C                some college           NaN
# 2             2        group B             master's degree      standard
# 3             3        group A          associate's degree           NaN
# 4             4        group C                some college      standard
# ..          ...            ...                         ...           ...
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# ...

# %%
data.fillna(method ='bfill')
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0             0        group B           bachelor's degree      standard
# 1             1        group C                some college      standard
# 2             2        group B             master's degree      standard
# 3             3        group A          associate's degree      standard
# 4             4        group C                some college      standard
# ..          ...            ...                         ...           ...
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# ...

# %% [markdown]
# <font size="4"><b> Pivot table</b>

# %%
pivot1 = pd.pivot_table(data, index=['lunch'], aggfunc='mean')
pivot1
# Out:
#               Unnamed: 0  math percentage  reading score percentage
# lunch
# free/reduced  513.915254         0.589548                  0.646751
# none           26.000000         0.540000                  0.550000
# standard      493.847589         0.700373                  0.716532

# %%
pd.pivot_table(data, index=['parental level of education','lunch'], aggfunc='count')
# Out:
#                                           Unnamed: 0  math percentage  \
# parental level of education lunch
# associate's degree          free/reduced          76               76
#                             standard             145              145
# bachelor's degree           free/reduced          44               44
#                             standard              73               73
# high school                 free/reduced          70               70
#                             standard             125              125
# master's degree             free/reduced          24               24
#                             standard              35               35
# some college                free/reduced          79               79
#                             standard             145              145
# some high school            free/reduced          61               61
#                             standard             118              118
# ...

# %% [markdown]
# <font size="4"><b> Query method</b>

# %%
data1 = data
data1
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0             0        group B           bachelor's degree      standard
# 1             1        group C                some college           NaN
# 2             2        group B             master's degree      standard
# 3             3        group A          associate's degree           NaN
# 4             4        group C                some college      standard
# ..          ...            ...                         ...           ...
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# ...

# %%
data1.fillna(method='bfill')
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0             0        group B           bachelor's degree      standard
# 1             1        group C                some college      standard
# 2             2        group B             master's degree      standard
# 3             3        group A          associate's degree      standard
# 4             4        group C                some college      standard
# ..          ...            ...                         ...           ...
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# ...

# %%
df = pd.DataFrame(data1)
df
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0             0        group B           bachelor's degree      standard
# 1             1        group C                some college           NaN
# 2             2        group B             master's degree      standard
# 3             3        group A          associate's degree           NaN
# 4             4        group C                some college      standard
# ..          ...            ...                         ...           ...
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# ...

# %%
data.query("lunch == standard")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# C:\ProgramData\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# C:\ProgramData\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'standard'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
