# %% [markdown]
# # <font size="7"><center> <u>2248048 - CAT 3 </u></center>

# %% [markdown]
# <font size="4"><b>Load the given “pollution_2010.csv” file into a pandas dataframe</b>

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Prerana Murthy\\Documents\\Christ\\MSc\\Python\\pollution_2010.csv")
df
# Out:
#       Year  Month   Day  Hour  PM2.5  Temperature
# 0     2010    1.0   1.0   0.0  170.0        -11.0
# 1     2010    1.0   1.0   1.0  149.0        -12.0
# 2     2010    1.0   1.0   2.0  154.0        -11.0
# 3     2010    1.0   1.0   3.0  164.0        -14.0
# 4     2010    1.0   1.0   4.0    NaN        -12.0
# ...    ...    ...   ...   ...    ...          ...
# 8755  2010   12.0  31.0  19.0   27.0         -5.0
# 8756  2010   12.0  31.0  20.0   17.0         -6.0
# 8757  2010   12.0  31.0  21.0   19.0         -6.0
# 8758  2010   12.0  31.0  22.0   16.0         -7.0
# 8759  2010   12.0  31.0  23.0   22.0         -7.0
#
# [8760 rows x 6 columns]

# %% [markdown]
# <font size="4"><b>1) Displaying the first 7 rows</b>

# %%
df.head(7)
# Out:
#    Year  Month  Day  Hour  PM2.5  Temperature
# 0  2010    1.0  1.0   0.0  170.0        -11.0
# 1  2010    1.0  1.0   1.0  149.0        -12.0
# 2  2010    1.0  1.0   2.0  154.0        -11.0
# 3  2010    1.0  1.0   3.0  164.0        -14.0
# 4  2010    1.0  1.0   4.0    NaN        -12.0
# 5  2010    1.0  1.0   5.0    NaN        -10.0
# 6  2010    1.0  1.0   6.0    NaN         -9.0

# %% [markdown]
# <font size = "4"><b>2) summarizing the dataset</b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         8760 non-null   int64
#  1   Month        8040 non-null   float64
#  2   Day          8729 non-null   float64
#  3   Hour         8732 non-null   float64
#  4   PM2.5        8081 non-null   float64
#  5   Temperature  8748 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 410.8 KB

# %%
df.describe()
# Out:
#          Year        Month          Day         Hour        PM2.5  Temperature
# count  8760.0  8040.000000  8729.000000  8732.000000  8081.000000  8748.000000
# mean   2010.0     6.125373    15.730782    11.503665   104.198985    11.606196
# std       0.0     3.316712     8.804862     6.922008    92.282310    12.607142
# min    2010.0     1.000000     1.000000     0.000000     1.000000   -19.000000
# 25%    2010.0     3.000000     8.000000     6.000000    35.000000     1.000000
# 50%    2010.0     6.000000    16.000000    12.000000    79.000000    12.000000
# 75%    2010.0     9.000000    23.000000    18.000000   147.000000    23.000000
# max    2010.0    12.000000    31.000000    23.000000   980.000000    41.000000

# %% [markdown]
# <font size = "4"><b>3) specifying descriptive statistics

# %%
df.describe()
# Out:
#          Year        Month          Day         Hour        PM2.5  Temperature
# count  8760.0  8040.000000  8729.000000  8732.000000  8081.000000  8748.000000
# mean   2010.0     6.125373    15.730782    11.503665   104.198985    11.606196
# std       0.0     3.316712     8.804862     6.922008    92.282310    12.607142
# min    2010.0     1.000000     1.000000     0.000000     1.000000   -19.000000
# 25%    2010.0     3.000000     8.000000     6.000000    35.000000     1.000000
# 50%    2010.0     6.000000    16.000000    12.000000    79.000000    12.000000
# 75%    2010.0     9.000000    23.000000    18.000000   147.000000    23.000000
# max    2010.0    12.000000    31.000000    23.000000   980.000000    41.000000

# %% [markdown]
# <font size = "4"><b>4) displaying the number of unique values

# %%
df.nunique()
# Out:
# Year             1
# Month           11
# Day             31
# Hour            24
# PM2.5          481
# Temperature     61
# dtype: int64

# %% [markdown]
# <font size = "4"><b>5) sub-setting using loc and iloc

# %%
df.loc[:,'Hour']
# Out:
# 0        0.0
# 1        1.0
# 2        2.0
# 3        3.0
# 4        4.0
#         ...
# 8755    19.0
# 8756    20.0
# 8757    21.0
# 8758    22.0
# 8759    23.0
# Name: Hour, Length: 8760, dtype: float64

# %%
df.loc[df['Month'] == 11.0]
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, Hour, PM2.5, Temperature]
# Index: []

# %%
df.iloc[3]
# Out:
# Year           2010.0
# Month             1.0
# Day               1.0
# Hour              3.0
# PM2.5           164.0
# Temperature     -14.0
# Name: 3, dtype: float64

# %%
df.iloc[4:8]
# Out:
#    Year  Month  Day  Hour  PM2.5  Temperature
# 4  2010    1.0  1.0   4.0    NaN        -12.0
# 5  2010    1.0  1.0   5.0    NaN        -10.0
# 6  2010    1.0  1.0   6.0    NaN         -9.0
# 7  2010    1.0  1.0   7.0    NaN         -9.0

# %% [markdown]
# <font size = "4"><b>6) detecting the missing values

# %%
df.isnull()
# Out:
#        Year  Month    Day   Hour  PM2.5  Temperature
# 0     False  False  False  False  False        False
# 1     False  False  False  False  False        False
# 2     False  False  False  False  False        False
# 3     False  False  False  False  False        False
# 4     False  False  False  False   True        False
# ...     ...    ...    ...    ...    ...          ...
# 8755  False  False  False  False  False        False
# 8756  False  False  False  False  False        False
# 8757  False  False  False  False  False        False
# 8758  False  False  False  False  False        False
# 8759  False  False  False  False  False        False
#
# [8760 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Year             0
# Month          720
# Day             31
# Hour            28
# PM2.5          679
# Temperature     12
# dtype: int64

# %% [markdown]
# <font size = "4"><b>7) removing the missing values

# %%
df1 = df.copy()
df1
# Out:
#       Year  Month   Day  Hour  PM2.5  Temperature
# 0     2010    1.0   1.0   0.0  170.0        -11.0
# 1     2010    1.0   1.0   1.0  149.0        -12.0
# 2     2010    1.0   1.0   2.0  154.0        -11.0
# 3     2010    1.0   1.0   3.0  164.0        -14.0
# 4     2010    1.0   1.0   4.0    NaN        -12.0
# ...    ...    ...   ...   ...    ...          ...
# 8755  2010   12.0  31.0  19.0   27.0         -5.0
# 8756  2010   12.0  31.0  20.0   17.0         -6.0
# 8757  2010   12.0  31.0  21.0   19.0         -6.0
# 8758  2010   12.0  31.0  22.0   16.0         -7.0
# 8759  2010   12.0  31.0  23.0   22.0         -7.0
#
# [8760 rows x 6 columns]

# %%
df1.dropna(inplace=True)
df1
# Out:
#       Year  Month   Day  Hour  PM2.5  Temperature
# 0     2010    1.0   1.0   0.0  170.0        -11.0
# 1     2010    1.0   1.0   1.0  149.0        -12.0
# 2     2010    1.0   1.0   2.0  154.0        -11.0
# 3     2010    1.0   1.0   3.0  164.0        -14.0
# 13    2010    1.0   1.0  13.0  170.0         -3.0
# ...    ...    ...   ...   ...    ...          ...
# 8755  2010   12.0  31.0  19.0   27.0         -5.0
# 8756  2010   12.0  31.0  20.0   17.0         -6.0
# 8757  2010   12.0  31.0  21.0   19.0         -6.0
# 8758  2010   12.0  31.0  22.0   16.0         -7.0
# 8759  2010   12.0  31.0  23.0   22.0         -7.0
#
# [7349 rows x 6 columns]

# %% [markdown]
# <font size = "4"><b>8) filling in missing values

# %%
df.fillna(method='ffill', inplace=True)
df.head(5)
# Out:
#    Year  Month  Day  Hour  PM2.5  Temperature
# 0  2010    1.0  1.0   0.0  170.0        -11.0
# 1  2010    1.0  1.0   1.0  149.0        -12.0
# 2  2010    1.0  1.0   2.0  154.0        -11.0
# 3  2010    1.0  1.0   3.0  164.0        -14.0
# 4  2010    1.0  1.0   4.0  164.0        -12.0

# %% [markdown]
# <font size = "4"><b>9) visualizing the data with a histogram

# %%
import matplotlib.pyplot as plt
df.hist('Temperature',bins=10, color='black', edgecolor='white')
plt.grid(False)

# %%
import matplotlib.pyplot as plt
df.hist('PM2.5',bins=20, color='cyan', edgecolor='black')
plt.grid(False)

# %% [markdown]
# <font size = "4"><b>10) visualizing the data with a scatter plot

# %%
df.plot.scatter('Temperature', 'PM2.5', s = 50, c = 'red', marker = '*', figsize=(10,10));
